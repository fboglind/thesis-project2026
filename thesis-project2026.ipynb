# %%
import pandas as pd
import numpy as np
import re
import json
from pathlib import Path

# %%
DATA_DIR = Path('data/xlsx')
CSV_DIR = Path('data/csv')
PROCESSED_DIR = Path('data/processed')
BNT_XLSX_PATH= DATA_DIR / 'BNT-syntheticData_v2.xlsx'
FAS_XLSX_PATH=DATA_DIR / 'FAS-syntheticData_v1.xlsx' 
SVF_XLSX_PATH=DATA_DIR / 'SVF-syntheticData_v1.xlsx'
MODEL_DIR = Path("/kbbert-swe/kbbert_swe")

# %%
xlsx_bnt=pd.read_excel(BNT_XLSX_PATH)
xlsx_fas=pd.read_excel(FAS_XLSX_PATH)
xlsx_svf=pd.read_excel(SVF_XLSX_PATH)
#convert to csv
xlsx_svf.to_csv(DATA_DIR/"svf_v1.csv", index=None, header=True)
df_svf = pd.DataFrame(pd.read_csv(DATA_DIR/"svf_v1.csv"))
xlsx_bnt.to_csv(DATA_DIR/"bnt_v2.csv", index=None, header=True)
df_bnt = pd.DataFrame(pd.read_csv(DATA_DIR/"bnt_v2.csv"))
xlsx_fas.to_csv(DATA_DIR/"fas_v1.csv", index=None, header=True)
df_fas = pd.DataFrame(pd.read_csv(DATA_DIR/"fas_v1.csv"))

# %%
xlsx_bnt.head()
# Out:
#          Gold  Unnamed: 1             User-1           User-2       User-2.1  \
# 0        säng         NaN            en säng         en möbel           säng
# 1       penna         NaN           en penna  en blyertspenna          penna
# 2  visselpipa         NaN  visselpipa är det             pipa  en visselpipa
# 3         kam         NaN                kam           hårkam            kam
# 4         såg         NaN                såg          verktyg            såg
#
#            User-4         User-5       User-6         User-7   User-8  ...  \
# 0            säng  en liten säng  en sovplats           säng  en säng  ...
# 1    blyertspenna   skrivredskap     en penna       kulspets    penna  ...
# 2  blåsinstrument     signalpipa    domarpipa         vissla     pipa  ...
# 3          borste            kam          kam  frisörverktyg      kam  ...
# 4         handsåg     sågverktyg          såg      maskinsåg      såg  ...
#
# ...

# %%
df_bnt.head()
# Out:
#          Gold  Unnamed: 1             User-1           User-2       User-2.1  \
# 0        säng         NaN            en säng         en möbel           säng
# 1       penna         NaN           en penna  en blyertspenna          penna
# 2  visselpipa         NaN  visselpipa är det             pipa  en visselpipa
# 3         kam         NaN                kam           hårkam            kam
# 4         såg         NaN                såg          verktyg            såg
#
#            User-4         User-5       User-6         User-7   User-8  ...  \
# 0            säng  en liten säng  en sovplats           säng  en säng  ...
# 1    blyertspenna   skrivredskap     en penna       kulspets    penna  ...
# 2  blåsinstrument     signalpipa    domarpipa         vissla     pipa  ...
# 3          borste            kam          kam  frisörverktyg      kam  ...
# 4         handsåg     sågverktyg          såg      maskinsåg      såg  ...
#
# ...
