# %%
import os
import pandas as pd
import numpy as np
import re
import json
from pathlib import Path
import yaml

# %%
# Load config
with open('../configs/_default_configs.yaml', 'r') as f:
    config = yaml.safe_load(f)

# Define paths
PROJECT_ROOT = Path(os.getcwd()).parent
DATA_DIR = PROJECT_ROOT / config['paths']['data_dir']
PROCESSED_DATA_DIR = PROJECT_ROOT / config['paths']['processed_data_dir']
NOTEBOOKS_DIR = PROJECT_ROOT / config['paths']['notebooks_dir']
MODEL_DIR = PROJECT_ROOT / config['paths']['model_dir']

# %%
df_bnt=pd.read_excel(BNT_XLSX_PATH)
df_bnt.head()

# %%
df_bnt=pd.read_excel(BNT_XLSX_PATH)
df_fas=pd.read_excel(FAS_XLSX_PATH)
df_svf=pd.read_excel(SVF_XLSX_PATH)
# #convert to csv
# df_xlsx_svf.to_csv(DATA_DIR/"svf_v1.csv", index=None, header=True)
# df_svf = pd.DataFrame(pd.read_csv(DATA_DIR/"svf_v1.csv"))
# df_xlsx_bnt.to_csv(DATA_DIR/"bnt_v2.csv", index=None, header=True)
# df_bnt = pd.DataFrame(pd.read_csv(DATA_DIR/"bnt_v2.csv"))
# df_xlsx_fas.to_csv(DATA_DIR/"fas_v1.csv", index=None, header=True)
# df_fas = pd.DataFrame(pd.read_csv(DATA_DIR/"fas_v1.csv"))

# %%
df_bnt.head()
